# %%
import random
import time
from IPython.display import HTML, display, clear_output

class Dealer:
    def __init__(self, deck_amount, name):
        self.make_deck(deck_amount)
        self.name=name
        self.hand = []
        self.status = False
        self.people = []
        pass
    
    def pass_cards(self, players):
        for player in  players:
            if player == players[0]:
                player.hand.append(self.playable_deck.pop(0))
                player.hidden = self.playable_deck.pop(0)
            else:
                player.hand = self.playable_deck[:2]
                self.playable_deck.pop(0)
                self.playable_deck.pop(0)
            if player.get_value() == 21 and player != players[0]:
                player.status = False
                player.bankroll += player.bet + player.bet//2
                player.bet = 0
                print(player.name, "balckjack!")
        print(self.playable_deck)
        
        pass
    def deal_cards(self):
        pass
    
    
    def shuffle(self, deck, discard):
        if self.discard:
            self.deck.append(self.discard)
        random.shuffle(self.deck)
        return(self.deck)
    
    def make_deck(self, decks_used):
        ranks = ['2', '3', '4', '5', '6', '7', '8', '9', '10', 'Jack', 'Queen', 'King', 'Ace']
        single_suit = [rank for rank in ranks]
        num_decks = 4*decks_used
        full_deck = single_suit * num_decks
        random.shuffle(full_deck)
        self.playable_deck = full_deck
        
    
    def Discard(self):
        pass
    
    def get_value(self):
        self.value = 0
        for card in self.hand:
            if card == "Jack" or card == "Queen" or card == "King":
                self.value += 10
            elif card == "Ace":
                if self.value + 11 > 21:
                    self.value +=1
                else:
                    self.value += 11
            else:
                self.value += int(card)
        return self.value
    
    pass

# %%
class Initiate_game:
    def __init__(self):
        while True:
            try:
                self.num_decks = int(input("how many decks do you want to play with? \nPlease type 1-8\n"))
                if 1 <= self.num_decks <= 8:
                    break
                else:
                    print("Please enter a number between 1 and 8.")
            except ValueError:
                print("Invalid input. Please eneter a valid number")
        
        while True:
            try:
                self.amount_players = int(input("how many players do you want to play with? \nPlease type 0-2\n"))
                if 0 <= self.amount_players <= 2:
                    break
                else:
                    print("Please enter a number between 0 and 2.")
            except ValueError:
                print("Invalid input. Please eneter a valid number")
        
        self.make_stage()
        pass
    
    def make_stage(self):
        names = ['Jill', 'Valerie', 'Kadeeja', 'Arnold', 'Brian', 'Sarah', 'Steve', 'Ryan', 'Javan', 'Ricardo', 'Nathan']
        
        players = [Dealer(int(self.num_decks), names.pop(random.randint(0, 9)))]
        players.append(Player())
        self.size = len(players[0].playable_deck)
        
        if int(self.amount_players):
            for i in range(1, int(self.amount_players) + 1):
                players.append(Players_ai(names.pop(random.randint(0, len(players)))))
                
        self.play(players)
        
    def play(self, players):
        time.sleep(0.2)
        while True:
            try:
                choice = int(input("How much would you like to bet? Choose between 10-100: \n"))
                if 10 <= choice <= 100:
                    break 
                else:
                    print("Please enter a number between 10 and 100.")
            except ValueError:
                print("Invalid input. Please eneter a valid number")
        
        players[1].bet = choice
        players[0].pass_cards(players)
        
        self.display_board(players)
        
        for player in players:
            player.people = players
            if player.status == True:
                event = player.make_decision()
                self.display_board(players)
                while event == 'hit':
                    event = player.make_decision()
                    self.display_board(players)
                
                
        players[0].hand.append(players[0].hidden)
        self.display_board(players)
        
        while players[0].get_value() < 16:
            players[0].hand.append(players[0].playable_deck.pop(0))
            self.display_board(players)
        
        
        for player in players:
            if player != players[0]:
                if player.status == False and player == players[1]:
                    print('BLACKJACK')
                elif player.get_value() > players[0].value and player.value <=21 and player.status == True:
                    player.bankroll += player.bet
                    player.bet = 0
                    if player == players[1]:
                        print('winner')
                
                elif player.value == players[0].value:
                    if player == players[1]:
                        print('push')
                    player.bet = 0
                
                else:
                    if player == players[1]:
                        print('loser')
                    player.bankroll -= player.bet
                    player.bet = 0
                player.status = True
        players[0].hand =[]
        
        if players[1].bankroll >= 10:
            self.play(players)
        else:
            players.pop(1)
            players.append(Players_ai(names.pop(random.randint(0, len(players)))))
    
        
    def display_board(self, players):
        clear_output()
        center = '<style>.output div p {text-align: center;}</style>'
        center2 = '<style>.output div h1 {text-align: center; font-size: 83px; margin: 0; padding: 0; font-weight: normal; }</style>'
        
        card_faces = {
            'blank': '🂠',
            'Ace': ['🂡','🂱','🃁','🃑'],
            '2': ['🂢','🂲','🃂','🃒'],
            '3': ['🂣','🂳','🃃','🃓'],
            '4': ['🂤','🂴','🃄', '🃔'],
            '5': ['🂥','🂵','🃅','🃕'],
            '6': ['🂦','🂶','🃆','🃖'],
            '7': ['🂧','🂷','🃇','🃗'],
            '8': ['🂨','🂸','🃈','🃘'],
            '9': ['🂩','🂹','🃉','🃙'],
            '10': ['🂪','🂺','🃊','🃚'],
            'Jack': ['🂫','🂻','🃋','🃛'],
            'Queen': ['🂭','🂽','🃍','🃝'],
            'King': ['🂮','🂾','🃎','🃞']
        }
    
        card_lst = ['']
        for player in players:
            for card in player.hand:
                card_lst[-1] += card_faces[card][random.randint(0,3)]
            card_lst.append('')
        
        if len(card_lst[0]) == 1:
            card_lst[0] += card_faces['blank']
        
        
        
        #when trying to get the text to display with something like justify content it would make the output: ('"(''
        #I refuse to work on this any longer so instead I'm resorting to this monstrosity
        #the only man that can judge me is Mr. Python himself
        if len(players) == 2:
            display(HTML(f'{center, center2}<p>Dealer</p> <p>{players[0].name}</p>  <h1>{card_lst[0]}</h1>  <p>‎</p><p>‎</p>  <h1>{card_lst[1]}</h1>  <p>{players[1].name}</p> <p>bet: \${players[1].bet} bankroll: \${players[1].bankroll}</p>'))
        elif len(players) == 3:
            display(HTML(f'{center, center2}<p>Dealer</p> <p>{players[0].name}</p> <h1>{card_lst[0]}</h1> <p>‎</p><p>‎</p> <h1>{card_lst[1]}&nbsp;&nbsp;&nbsp;&nbsp;{card_lst[2]}</h1> <p>{players[1].name}&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;{players[2].name}</p> <p>bet: \${players[1].bet} bankroll: \${players[1].bankroll}</p>'))
        elif len(players) == 4:
            display(HTML(f'{center, center2}<p>Dealer</p> <p>{players[0].name}</p> <h1>{card_lst[0]}</h1> <p>‎</p><p>‎</p> <h1>{card_lst[1]}&nbsp;&nbsp;&nbsp;&nbsp;{card_lst[2]}&nbsp;&nbsp;&nbsp;&nbsp;{card_lst[3]}</h1> <p>{players[1].name}&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;{players[2].name}&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;{players[3].name}</p> <p>bet: \${players[1].bet} bankroll: \${players[1].bankroll}</p>'))
        else:
            print("player error in display")
        
        time.sleep(2.5)

# %%
class Players_ai:
    def __init__(self, name):
        self.name = name
        self.style = random.randint(1, 3)
        self.hand = []
        self.status = True
        self.people = []
        self.bankroll = 1000
        self.bet = 50
        pass

    def hit(self):
        self.hand.append(self.people[0].playable_deck.pop(0))
        pass
    
    def get_value(self):
        self.value = 0
        aces = 0
        for card in self.hand:
            if card == "Jack" or card == "Queen" or card == "King":
                self.value += 10
            elif card == "Ace":
                aces +=1
            else:
                self.value += int(card)
        while aces > 0:
            if self.value + 11 <= 21:
                self.value += 11
                aces -= 1
            else:
                self.value += 1
                aces -=1
        return self.value

    def make_decision(self):
        self.get_value()
                
        if self.name == 'Nathan':
            self.bet = 100
            card = self.people[0].playable_deck[0]
                
            if card == "Jack" or card == "Queen" or card == "King":
                if self.value + 10 <=21:
                    self.hit()
                    return 'hit'
                else:
                    return 'stand'
            elif card == "Ace":
                if self.value + 11 <= 21:
                        self.hit()
                        return 'hit'
                else:
                    if self.value + 1 <= 21:
                        self.hit()
                        return 'hit'
                    else:
                        return 'stand'
            else:
                if self.value + int(card) <= 21:
                    self.hit()
                    return 'hit'
                return ' stand'
            
        elif self.style == 1:
            self.bet = random.randint(30,60)
            if self.value <= 14:
                self.hit()
                return 'hit'
            else:
                return 'stand'
        
        elif self.style == 2:
            self.bet = random.randint(10,30)
            if self.value <= 12:
                self.hit()
                return 'hit'
            else:
                return 'stand'
        else:
            self.bet = random.randint(70,100)
            if self.value <= 16:
                self.hit()
                return 'hit'
            else:
                return 'stand'

# %%
class Player:
    def __init__(self):
        self.hand = []
        self.status = True
        self.name = 'you'
        self.people = []
        self.bankroll = 1000
        pass

    def hit(self):
        self.hand.append(self.people[0].playable_deck.pop(0))
        print(self.hand)
        pass

    
    def get_value(self):
        self.value = 0
        aces = 0
        for card in self.hand:
            if card == "Jack" or card == "Queen" or card == "King":
                self.value += 10
            elif card == "Ace":
                aces +=1
            else:
                self.value += int(card)
        while aces > 0:
            if self.value + 11 <= 21:
                self.value += 11
                aces -= 1
            else:
                self.value += 1
                aces -=1
        return self.value

    def make_decision(self):
        while True:
                ui = input("hit or stand? \n")
                if ui.lower().strip() == 'hit' or ui.lower().strip() == 'stand':
                    break 
                else:
                    print("type either hit or stand")
        if ui.lower() == "hit":
            self.hit()
            if self.get_value() > 21:
                return 'bust'
            return 'hit'
        return 'stand'

# %%
x = Initiate_game()
# Out:
# ('<style>.output div p {text-align: center;}</style>', '<style>.output div h1 {text-align: center; font-size: 83px; margin: 0; padding: 0; font-weight: normal; }</style>')<p>Dealer</p> <p>Ricardo</p> <h1>🃖🂠</h1> <p>‎</p><p>‎</p> <h1>🃑🂧&nbsp;&nbsp;&nbsp;&nbsp;🂤🃗&nbsp;&nbsp;&nbsp;&nbsp;🃘🂳</h1> <p>you&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Kadeeja&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Arnold</p> <p>bet: \$10 bankroll: \$1000</p>
